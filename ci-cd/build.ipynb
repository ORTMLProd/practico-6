# %%
# !aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 259504422128.dkr.ecr.us-east-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# !docker build -t model-plata -f Dockerfile .
# Out:
# Sending build context to Docker daemon  12.48MB
# Step 1/11 : FROM ubuntu:20.04
# 20.04: Pulling from library/ubuntu
#
# Digest: sha256:ed4a42283d9943135ed87d4ee34e542f7f5ad9ecf2f244870e23122f703f91c2[1A
# Status: Downloaded newer image for ubuntu:20.04
#  ---> bf40b7bc7a11
# Step 2/11 : RUN apt-get update && apt-get upgrade -y
#  ---> Running in 044eda9794a3
# Get:1 http://archive.ubuntu.com/ubuntu focal InRelease [265 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/restricted amd64 Packages [33.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 Packages [11.3 MB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 Packages [1275 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [177 kB]
# ...

# %%
# !docker tag model-plata 259504422128.dkr.ecr.us-east-1.amazonaws.com/plata-model-registry:model-plata

# %%
# !docker push 259504422128.dkr.ecr.us-east-1.amazonaws.com/plata-model-registry:model-plata
# Out:
# The push refers to repository [259504422128.dkr.ecr.us-east-1.amazonaws.com/plata-model-registry]
#
# 065de756: Preparing
# 4cbcdf90: Preparing
# da974fb2: Preparing
# e72f5909: Preparing
# b881bd1b: Preparing
# af6bb3d8: Preparing
# 065de756: Pushed   1.077GB/1.046GB2KPushing  858.9MB/1.046GBPushing   1.05GBmodel-plata: digest: sha256:2211271c4703affb3526c5ca48709be607e496c55534991d73775d02b464091b size: 1794
